# %%
def FindAlternateGroups(url):
    
    num = 1
    url = url.rsplit("=", 1)
    url = url[0]+ '='
    extracted_data = []
    while True:
      try:
        # Send GET request to the URL
        response = requests.get(url+ str(num))
        num= int(num)+1
        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the JSON response
            data = json.loads(response.text)
        
            # Extract the desired information from the data
            for product in data['products']:
                extracted_data.append({
                    'title': product['title'],
                    'id': product['id'] ,
                    'handle': product['handle'],
                    'vendor': product['vendor'],
                    'product_type': product['product_type'],
                    'tags':product['tags'],
                    'variants': product['variants'] 
                })
        else:
            print("Request failed with status code:", response.status_code)
            break
      
      except Exception as e:
          break
    
    # Convert the extracted data to JSON format
    json_data = json.dumps(extracted_data, indent=4)

    df = pd.read_json(json_data, orient='columns')
    
    df['variants_url']=""
    for j in range(len(df)):
      df['variants_url'][j] = ['https://www.boysnextdoor-apparel.co/products/'+ df['handle'][j]+ '?variant=' + str(df.iloc[j]['variants'][i]['id']) for i in range(len(df.iloc[j]['variants']))]
        
    df.drop(['variants'],axis = 1,inplace=True)
    
    # Group URLs by Product Category
    grouped_urls = df.groupby('product_type')['variants_url'].apply(list).to_dict()

    # Convert to JSON format
    json_output = json.dumps(grouped_urls, indent =4)

    return json_output

# %%
FindAlternateGroups('https://www.boysnextdoor-apparel.co/collections/all/products.json?page=1')
# Out:
# Request failed with status code: 430
# <ipython-input-40-f3445174308d>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['variants_url'][j] = ['https://www.boysnextdoor-apparel.co/products/'+ df['handle'][j]+ '?variant=' + str(df.iloc[j]['variants'][i]['id']) for i in range(len(df.iloc[j]['variants']))]
# ...

# %%
url = "https://www.boysnextdoor-apparel.co/collections/all/products.json?page=100"
url = url.rsplit("=", 1)
url = url[0]+ '='
url
# Out:
# 'https://www.boysnextdoor-apparel.co/collections/all/products.json?page='

# %%
import pandas as pd 
import json

# %%
# Convert the extracted data to JSON format
json_data = json.dumps(extracted_data, indent=4)

# Print the JSON data
print(json_data)

# %%
df = pd.read_json(json_data, orient='columns')

# %%
df
# Out:
#                                           title             id  \
# 0      A.P.C. Daniela Logo-Print Denim Tote Bag  5751418519702
# 1                  and Wander Dyneema Stuffsack  7728812490978
# 2         and Wander Heather Waist Bag Charcoal  7696930504930
# 3             and Wander Heather Waist Bag Navy  7696940531938
# 4    Axel Arigato Marathon Sneaker White Silver  7767737467106
# ..                                          ...            ...
# 665           Wood Wood Low Profile Mondana Cap  7728767860962
# 666        WYM Heavy Weight Basic Big-Tee Beige  7693151174882
# 667         WYM Heavy Weight Basic Big-Tee Blue  7693155107042
# 668         WYM Heavy Weight Basic Big-Tee Grey  7693148520674
# 669        WYM Heavy Weight Basic Big-Tee White  7693125714146
#
#                                          handle  \
# 0       a-p-c-daniela-logo-print-denim-tote-bag
# 1                  and-wander-dyneema-stuffsack
# 2         and-wander-heather-waist-bag-charcoal
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/projects/data.csv')

# %%
import os
os.chdir('/content')

# %%
df.to_csv("/content/drive/MyDrive/projects/data.csv", index = False)

# %%
df.iloc[0]['variants']['id']
# Out:
# "[{'id': 36425838559382, 'title': 'Default Title', 'option1': 'Default Title', 'option2': None, 'option3': None, 'sku': '', 'requires_shipping': True, 'taxable': False, 'featured_image': None, 'available': True, 'price': '799.00', 'grams': 500, 'compare_at_price': '899.00', 'position': 1, 'product_id': 5751418519702, 'created_at': '2020-09-22T18:29:20+08:00', 'updated_at': '2023-03-10T02:06:10+08:00'}]"

# %%
df['variants_url']=""

# %%
for j in range(len(df)):
  df['variants_url'][j] = ['https://www.boysnextdoor-apparel.co/products/'+ df['handle'][j]+ '?variant=' + str(df.iloc[j]['variants'][i]['id']) for i in range(len(df.iloc[j]['variants']))]
# Out:
# <ipython-input-34-02cfd3634d8e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['variants_url'][j] = ['https://www.boysnextdoor-apparel.co/products/'+ df['handle'][j]+ '?variant=' + str(df.iloc[j]['variants'][i]['id']) for i in range(len(df.iloc[j]['variants']))]

# %%
l = ['https://www.boysnextdoor-apparel.co/products/'+ df['handle'][2]+ '?variant=' + str(df.iloc[2]['variants'][i]['id']) for i in range(len(df.iloc[2]['variants']))]

# %%
l
# Out:
# ['https://www.boysnextdoor-apparel.co/products/and-wander-heather-waist-bag-charcoal?variant=42746265075938',
#  'https://www.boysnextdoor-apparel.co/products/and-wander-heather-waist-bag-charcoal?variant=42746229522658']

# %%
df.drop(['body_html', 'variants'],axis = 1,inplace=True)
df
# Out:
#                                           title             id  \
# 0      A.P.C. Daniela Logo-Print Denim Tote Bag  5751418519702
# 1                  and Wander Dyneema Stuffsack  7728812490978
# 2         and Wander Heather Waist Bag Charcoal  7696930504930
# 3             and Wander Heather Waist Bag Navy  7696940531938
# 4    Axel Arigato Marathon Sneaker White Silver  7767737467106
# ..                                          ...            ...
# 665           Wood Wood Low Profile Mondana Cap  7728767860962
# 666        WYM Heavy Weight Basic Big-Tee Beige  7693151174882
# 667         WYM Heavy Weight Basic Big-Tee Blue  7693155107042
# 668         WYM Heavy Weight Basic Big-Tee Grey  7693148520674
# 669        WYM Heavy Weight Basic Big-Tee White  7693125714146
#
#                                          handle        vendor product_type  \
# 0       a-p-c-daniela-logo-print-denim-tote-bag           APC          Bag
# ...

# %%
# !pip install pandasai openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.7/797.7 kB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 125.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 78.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 109.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 19.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: ipython
# ...

# %%
import pandas as pd
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI
from pandasai.llm.open_assistant import OpenAssistant

# %%
import os
OPENAI_API_KEY = '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'
llm = OpenAI(api_token = OPENAI_API_KEY)

# %%
pandas_ai = PandasAI(llm)

# %%
pandas_ai.run(df, prompt='How many bag product_type are there?')
# Out:
# 'There are 80 bags in the product_type category.'

# %%
pandas_ai.run(df, prompt='How many types of product_type are there?')
# Out:
# 'There are 27 different types of product_type.'

# %%
pandas_ai.run(df, prompt='list the variants_url of products with product_type as shorts in json format.')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-18-7a2f77ef634e> in <cell line: 1>()
# ----> 1 pandas_ai.run(df, prompt='list the variants_url of products with product_type as shorts in json format.')
#
# /usr/local/lib/python3.10/dist-packages/pandasai/__init__.py in run(self, data_frame, prompt, is_conversational_answer, show_code, anonymize_df, use_error_correction_framework)
#     166             is_conversational_answer = self._is_conversational_answer
#     167         if is_conversational_answer:
# --> 168             answer = self.conversational_answer(prompt, code, answer)
#     169             self.log(f"Conversational answer: {answer}")
#     170         return answer
#
# /usr/local/lib/python3.10/dist-packages/pandasai/__init__.py in conversational_answer(self, question, code, answer)
#     105             question=question, code=code, answer=answer
# ...

# %%
# Group URLs by Product Category
grouped_urls = df.groupby('product_type')['variants_url'].apply(list).to_dict()

# Convert to JSON format
json_output = json.dumps(grouped_urls, indent =4)

print(json_output)
# Out:
# {
#     "AirPods Case": [
#         "['https://www.boysnextdoor-apparel.co/products/leather-factory-roberu-airpods-case-dark-brown?variant=36109855719574', 'https://www.boysnextdoor-apparel.co/products/leather-factory-roberu-airpods-case-dark-brown?variant=36109855752342', 'https://www.boysnextdoor-apparel.co/products/leather-factory-roberu-airpods-case-dark-brown?variant=36109855785110', 'https://www.boysnextdoor-apparel.co/products/leather-factory-roberu-airpods-case-dark-brown?variant=36109855817878', 'https://www.boysnextdoor-apparel.co/products/leather-factory-roberu-airpods-case-dark-brown?variant=36109855850646']",
# ...

# %%
df.iloc[2]['body_html']
# Out:
# '<p><meta charset="utf-8"><meta charset="UTF-8"><span data-mce-fragment="1">A light and sturdy waist bag from Japanese outdoor brand. Features adjustable waist strap, double zip fastening and adjustable front straps.\xa0Reflective logo printed on the front.\xa0<meta charset="UTF-8"> The waist back with compression tape. It can be used around the waist or on the shoulder.</span><br></p>\n<p><span>100% Polyester<br></span><span> Lining 100% nylon<br>Weight 190g<br></span></p>\n<h4>\n<br>Size &amp; Fit</h4>\n<p><meta charset="UTF-8">30cm W x 11cm H x 8cm D<br></p>\n<h4>Care &amp; Laundry</h4>\n<p><span>Machine wash according to instructions on care label</span></p>'

# %%
import re
html_clean = re.sub(r'[^\x00-\x7F]+', '', df.iloc[2]['body_html'])
html_clean
# Out:
# '<p><meta charset="utf-8"><meta charset="UTF-8"><span data-mce-fragment="1">A light and sturdy waist bag from Japanese outdoor brand. Features adjustable waist strap, double zip fastening and adjustable front straps.Reflective logo printed on the front.<meta charset="UTF-8"> The waist back with compression tape. It can be used around the waist or on the shoulder.</span><br></p>\n<p><span>100% Polyester<br></span><span> Lining 100% nylon<br>Weight 190g<br></span></p>\n<h4>\n<br>Size &amp; Fit</h4>\n<p><meta charset="UTF-8">30cm W x 11cm H x 8cm D<br></p>\n<h4>Care &amp; Laundry</h4>\n<p><span>Machine wash according to instructions on care label</span></p>'

# %%
import html

# %%
decoded_html = html.unescape(html_clean)
decoded_html
# Out:
# '<p><meta charset="utf-8"><meta charset="UTF-8"><span data-mce-fragment="1">A light and sturdy waist bag from Japanese outdoor brand. Features adjustable waist strap, double zip fastening and adjustable front straps.Reflective logo printed on the front.<meta charset="UTF-8"> The waist back with compression tape. It can be used around the waist or on the shoulder.</span><br></p>\n<p><span>100% Polyester<br></span><span> Lining 100% nylon<br>Weight 190g<br></span></p>\n<h4>\n<br>Size & Fit</h4>\n<p><meta charset="UTF-8">30cm W x 11cm H x 8cm D<br></p>\n<h4>Care & Laundry</h4>\n<p><span>Machine wash according to instructions on care label</span></p>'

# %%
decoded_html = decoded_html.replace('<meta charset="utf-8">', "")
decoded_html =decoded_html.replace('<meta charset="UTF-8">',"")
decoded_html
# Out:
# '<p><span data-mce-fragment="1">A light and sturdy waist bag from Japanese outdoor brand. Features adjustable waist strap, double zip fastening and adjustable front straps.Reflective logo printed on the front. The waist back with compression tape. It can be used around the waist or on the shoulder.</span><br></p>\n<p><span>100% Polyester<br></span><span> Lining 100% nylon<br>Weight 190g<br></span></p>\n<h4>\n<br>Size & Fit</h4>\n<p>30cm W x 11cm H x 8cm D<br></p>\n<h4>Care & Laundry</h4>\n<p><span>Machine wash according to instructions on care label</span></p>'

# %%
df.iloc[2]['variants'][1]['id']
# Out:
# 42746229522658

# %%
# !pip install python-dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
print(extracted_data)
# Out:
# [{'title': 'A.P.C. Daniela Logo-Print Denim Tote Bag', 'keys': dict_keys(['id', 'title', 'handle', 'body_html', 'published_at', 'created_at', 'updated_at', 'vendor', 'product_type', 'tags', 'variants', 'images', 'options'])}, {'title': 'and Wander Dyneema Stuffsack', 'keys': dict_keys(['id', 'title', 'handle', 'body_html', 'published_at', 'created_at', 'updated_at', 'vendor', 'product_type', 'tags', 'variants', 'images', 'options'])}, {'title': 'and Wander Heather Waist Bag Charcoal', 'keys': dict_keys(['id', 'title', 'handle', 'body_html', 'published_at', 'created_at', 'updated_at', 'vendor', 'product_type', 'tags', 'variants', 'images', 'options'])}, {'title': 'and Wander Heather Waist Bag Navy', 'keys': dict_keys(['id', 'title', 'handle', 'body_html', 'published_at', 'created_at', 'updated_at', 'vendor', 'product_type', 'tags', 'variants', 'images', 'options'])}, {'title': 'Axel Arigato Marathon Sneaker White Silver', 'keys': dict_keys(['id', 'title', 'handle', 'body_html', 'publi
# ...
